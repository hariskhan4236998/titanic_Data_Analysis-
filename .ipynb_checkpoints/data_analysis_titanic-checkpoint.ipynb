# %%
import pandas as pd

# %%
td = pd.read_csv("titanic datset.csv")

# %%
td
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
td.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
td.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
td.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
td.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
td['Pclass'].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
print("Mean Age:",td['Age'].mean())
print("Median:",td['Age'].median())
print("Mode of Embarked:", td['Embarked'].mode()[0])
# Out:
# Mean Age: 30.272590361445783
# Median: 27.0
# Mode of Embarked: S

# %%
print("Standard Deviation of Age:", td['Age'].std())
print("Variance of Age:", td['Age'].var())
print("Range of Fare:", td['Fare'].max() - td['Fare'].min())
# Out:
# Standard Deviation of Age: 14.18120923562442
# Variance of Age: 201.10669538455937
# Range of Fare: 512.3292

# %%
import matplotlib.pyplot as plt

# Plot a histogram for the 'Age' column
plt.hist(td['Age'].dropna(), bins=20, color='blue', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
td.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
td.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print("Mean Age:",td['Age'].mean())
print("Median:",td['Age'].median())
print("Mode of Embarked:", td['Embarked'].mode()[0])
# Out:
# Mean Age: 30.272590361445783
# Median: 27.0
# Mode of Embarked: S

# %%
print("Standard Deviation of Age:", td['Age'].std())
print("Variance of Age:", td['Age'].var())
print("Range of Fare:", td['Fare'].max() - td['Fare'].min())
# Out:
# Standard Deviation of Age: 14.18120923562442
# Variance of Age: 201.10669538455937
# Range of Fare: 512.3292

# %%
import matplotlib.pyplot as plt

plt.hist(td['Age'].dropna(), bins=20, color='blue', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
td['Survived'].value_counts().plot.pie(autopct='%1.1f%%', labels=['Not Survived', 'Survived'])
plt.title('Survival Rate')
plt.show()

# %%
import seaborn as sns


sns.boxplot(x='Pclass', y='Fare', data=td)
plt.title('Fare by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Fare')
plt.show()

# %%
print("Average Age and Fare by Survival Status:")
print(td.groupby('Survived')[['Age', 'Fare']].mean())
# Out:
# Average Age and Fare by Survival Status:
#                 Age       Fare
# Survived
# 0         30.272732  27.527877
# 1         30.272362  49.747699

# %%
print("Passenger Distribution by Class and Gender:")
print(td.groupby(['Pclass', 'Sex'])['PassengerId'].count())
# Out:
# Passenger Distribution by Class and Gender:
# Pclass  Sex
# 1       female     50
#         male       57
# 2       female     30
#         male       63
# 3       female     72
#         male      146
# Name: PassengerId, dtype: int64

# %%
td.fillna(td['Age'].mean(), inplace=True)


print("Missing values in 'Age' after filling:", td['Age'].isnull().sum())
# Out:
# Missing values in 'Age' after filling: 0

# %%
td = td.dropna(subset=['Embarked'])


print("Missing values in 'Embarked' after dropping:", td['Embarked'].isnull().sum())
# Out:
# Missing values in 'Embarked' after dropping: 0

# %%
td = td.dropna(subset=['Embarked'])


print("Missing values in 'Embarked' after dropping:", td['Embarked'].isnull().sum())
# Out:
# Missing values in 'Embarked' after dropping: 0

# %%
td.to_csv('td_cleaned.csv', index=False)
print("Cleaned dataset saved as 'titanic_cleaned.csv'")
# Out:
# Cleaned dataset saved as 'titanic_cleaned.csv'
